# %%
import pyautogui
import time
import pyperclip


pyautogui.PAUSE = 1
#abrir navegador
pyautogui.alert("Press OK to start the code")
pyautogui.hotkey('ctrl','t')

# %%
#abrir drive
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing"
pyperclip.copy(link)
pyautogui.hotkey('ctrl','v')
pyautogui.press('enter')
time.sleep(10)

# %%
#baixando a base de dados

pyautogui.click(x=384, y=284, clicks=2)
time.sleep(2)
pyautogui.click(x=395, y=445)
pyautogui.click(x=2353, y=161)
pyautogui.click(x=2058, y=555)
time.sleep(8)

# %%
#importando arquivo
import pandas as pd

df = pd.read_excel(r'C:\Users\User\Downloads\Vendas - Dez.xlsx')
display(df)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#calculando o faturamento

faturamento = df['Valor Final'].sum()
qtde_produtos = df['Quantidade'].sum()

# %%
#abrir aba do gmail
pyautogui.hotkey('ctrl','t')
pyautogui.write('mail.google.com')
pyautogui.press('enter')
time.sleep(5)

pyautogui.click(x=32, y=174)

# %%
#escrever e envcaminhar email
pyautogui.write('maria.duda3013@hotmail.com')
pyautogui.press('tab')
pyautogui.press('tab')
assunto = 'Relatório de Vendas de Ontem'
pyperclip.copy(assunto)
pyautogui.hotkey('ctrl','v')
pyautogui.press('tab')

texto = f"""
Prezados, bom dia

O faturamento de ontem foi de: R$ {faturamento:,.2f}
A quantidade de produtos foi de: {qtde_produtos:,}

Atenciosamente
Maria Eduarda"""

pyperclip.copy(texto)
pyautogui.hotkey('ctrl','v')
pyautogui.hotkey('ctrl','enter')
